# %%
import pandas as pd

# %%
df = pd.read_csv("datasets\AQIDataIndia.csv")

# %%
df.shape
# Out:
# (3359, 10)

# %%
x=pd.DataFrame(df)
print(x )
# Out:
#               state        city                                      station  \
# 0             Bihar  Kishanganj        SDM Office_Khagra, Kishanganj - BSPCB
# 1             Bihar  Kishanganj        SDM Office_Khagra, Kishanganj - BSPCB
# 2             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# 3             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# 4             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# ...             ...         ...                                          ...
# 3354    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3355    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3356    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3357  Uttar_Pradesh   Vrindavan             Omex Eternity, Vrindavan - UPPCB
# 3358    Uttarakhand    Kashipur  Govt. Girls Inter College, Kashipur - UKPCB
#
# ...

# %%
df2 = df.dropna()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3148 entries, 1 to 3358
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          3148 non-null   object
#  1   city           3148 non-null   object
#  2   station        3148 non-null   object
#  3   last_update    3148 non-null   object
#  4   latitude       3148 non-null   float64
#  5   longitude      3148 non-null   float64
#  6   pollutant_id   3148 non-null   object
#  7   pollutant_min  3148 non-null   float64
#  8   pollutant_max  3148 non-null   float64
#  9   pollutant_avg  3148 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 270.5+ KB

# %%
df2.isnull().sum()
# Out:
# state            0
# city             0
# station          0
# last_update      0
# latitude         0
# longitude        0
# pollutant_id     0
# pollutant_min    0
# pollutant_max    0
# pollutant_avg    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(x['city'],x['pollutant_max'])
plt.show()

# %%
x = df['city'].where(df['state']=='Bihar')
#plt.plot(x['city'],x['pollutant_max'])
# plt.show()
x
# Out:
# 0       Kishanganj
# 1       Kishanganj
# 2        Manguraha
# 3        Manguraha
# 4        Manguraha
#            ...
# 3354           NaN
# 3355           NaN
# 3356           NaN
# 3357           NaN
# 3358           NaN
# Name: city, Length: 3359, dtype: object

# %%
x
# Out:
# 0       Kishanganj
# 1       Kishanganj
# 2        Manguraha
# 3        Manguraha
# 4        Manguraha
#            ...
# 3354           NaN
# 3355           NaN
# 3356           NaN
# 3357           NaN
# 3358           NaN
# Name: city, Length: 3359, dtype: object

# %%
df
# Out:
#               state        city                                      station  \
# 0             Bihar  Kishanganj        SDM Office_Khagra, Kishanganj - BSPCB
# 1             Bihar  Kishanganj        SDM Office_Khagra, Kishanganj - BSPCB
# 2             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# 3             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# 4             Bihar   Manguraha         Forest Rest House, Manguraha - BSPCB
# ...             ...         ...                                          ...
# 3354    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3355    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3356    West_Bengal    Siliguri           Ward-32 Bapupara, Siliguri - WBPCB
# 3357  Uttar_Pradesh   Vrindavan             Omex Eternity, Vrindavan - UPPCB
# 3358    Uttarakhand    Kashipur  Govt. Girls Inter College, Kashipur - UKPCB
#
# ...

# %%
df.describe()
# Out:
#           latitude    longitude  pollutant_min  pollutant_max  pollutant_avg
# count  3359.000000  3359.000000    3148.000000    3148.000000    3148.000000
# mean     22.676211    78.581460      36.598158     105.235070      66.389454
# std       5.522318     4.847776      54.161807     116.504759      79.052099
# min       8.514909    70.909168       1.000000       1.000000       1.000000
# 25%      19.061749    75.555917       5.750000      19.000000      13.000000
# 50%      23.243639    77.310100      16.000000      64.500000      38.000000
# 75%      27.198658    80.327067      46.000000     141.000000      88.250000
# max      34.066206    94.636574     352.000000     500.000000     432.000000

# %%
x  = df['pollutant_max']
y = df['pollutant_avg']
z = df['pollutant_min']
dir(plt)
# Out:
# ['AbstractContextManager',
#  'Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'AxLine',
#  'Axes',
#  'BackendFilter',
#  'Button',
#  'Circle',
#  'Colorizer',
#  'ColorizingArtist',
#  'Colormap',
#  'Enum',
#  'ExitStack',
#  'Figure',
#  'FigureBase',
#  'FigureCanvasBase',
#  'FigureManagerBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MouseButton',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotSpec',
#  'TYPE_CHECKING',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_ColorizerInterface',
#  '_NO_PYPLOT_NOTE',
#  '_REPL_DISPLAYHOOK',
#  '_ReplDisplayHook',
#  '__annotations__',
# ...

# %%
plt.figure(figsize=(16,10))
plt.plot(x,label='xvalue',color='red')
plt.plot(y,label='yvalue',color='blue')
plt.plot(z,label='zvalue',color='green')
plt.title('Random Value')
plt.xlabel('x-axis')
plt.ylabel('y-label')
plt.legend()
plt.grid()

# %%
help(plt.subplot)
# Out:
# Help on function subplot in module matplotlib.pyplot:
#
# subplot(*args, **kwargs) -> 'Axes'
#     Add an Axes to the current figure or retrieve an existing Axes.
#
#     This is a wrapper of `.Figure.add_subplot` which provides additional
#     behavior when working with the implicit API (see the notes section).
#
#     Call signatures::
#
#        subplot(nrows, ncols, index, **kwargs)
#        subplot(pos, **kwargs)
#        subplot(**kwargs)
#        subplot(ax)
#
#     Parameters
#     ----------
#     *args : int, (int, int, *index*), or `.SubplotSpec`, default: (1, 1, 1)
#         The position of the subplot described by one of
#
#         - Three integers (*nrows*, *ncols*, *index*). The subplot will take the
#           *index* position on a grid with *nrows* rows and *ncols* columns.
#           *index* starts at 1 in the upper left corner and increases to the
#           right. *index* can also be a two-tuple specifying the (*first*,
# ...

# %%
# df['city'].where(df['state']=='Bihar' & df['city']=='Patna').dropna()
result = df[['city','state','pollutant_id','pollutant_max']].where(
    (df['city'] == 'Patna') & (df['pollutant_max'] > 100)
).dropna()

# %%
plt.scatter(result['pollutant_id'],result['pollutant_max'])
plt.legend()
plt.xlabel('pollutant_id')
plt.ylabel('pollutant_max')
plt.title('Patna')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4808\2371269350.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head(100)
# Out:
#            state        city                                station  \
# 0          Bihar  Kishanganj  SDM Office_Khagra, Kishanganj - BSPCB
# 1          Bihar  Kishanganj  SDM Office_Khagra, Kishanganj - BSPCB
# 2          Bihar   Manguraha   Forest Rest House, Manguraha - BSPCB
# 3          Bihar   Manguraha   Forest Rest House, Manguraha - BSPCB
# 4          Bihar   Manguraha   Forest Rest House, Manguraha - BSPCB
# ..           ...         ...                                    ...
# 95  Chhattisgarh       Korba                   Rampur, Korba - CECB
# 96  Chhattisgarh       Korba               Urja Nagar, Korba - CECB
# 97  Chhattisgarh   Kunjemura     OP Jindal School, Kunjemura - CECB
# 98  Chhattisgarh      Raipur                   AIIMS, Raipur - CECB
# 99  Chhattisgarh      Raipur                   AIIMS, Raipur - CECB
#
#          last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0   14-11-2025 21:00  26.088130  87.938403          NO2            NaN
# ...

# %%
import numpy as np

# %%
x1 = df['pollutant_min']
y1 = df['pollutant_max']
plt.plot(x1)
plt.plot(y1)

# %%
id = result['pollutant_id'].value_counts()
print(id)
# Out:
# pollutant_id
# PM2.5    5
# PM10     4
# CO       4
# NO2      2
# OZONE    1
# Name: count, dtype: int64

# %%
plt.pie(id,labels=id.index,autopct="%1.1f",explode=[0.1 for x in range(5)])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a9791ea5d0>,
# ...
#  [Text(0.6666842374971674, 0.9977635629109837, 'PM2.5'),
#   Text(-1.108655515199019, 0.4592199349100581, 'PM10'),
#   Text(-0.459219754287142, -1.108655590015428, 'CO'),
#   Text(0.8485284189686702, -0.8485278558789505, 'NO2'),
#   Text(1.1769423586950991, -0.2341082747559715, 'OZONE')],
#  [Text(0.38889913854001434, 0.5820287450314071, '31.2'),
#   Text(-0.6467157171994278, 0.2678782953642005, '25.0'),
#   Text(-0.2678781900008328, -0.6467157608423331, '25.0'),
#   Text(0.4949749110650576, -0.4949745825960545, '12.5'),
#   Text(0.6865497092388076, -0.1365631602743167, '6.2')])

# %%
result['pollutant_id']
# Out:
# 68       PM10
# 74         CO
# 88       PM10
# 720      PM10
# 1424      NO2
# 1425       CO
# 2096    PM2.5
# 2097    PM2.5
# 2098      NO2
# 2099    PM2.5
# 2743    PM2.5
# 2744     PM10
# 2768       CO
# 2769    PM2.5
# 2771       CO
# 2786    OZONE
# Name: pollutant_id, dtype: object

# %%
print(df['pollutant_id'].value_counts())
print('*'*20)
print(f'Unique {df.pollutant_id.nunique}')
df.pollutant_id.unique
# Out:
# pollutant_id
# NO2      496
# PM10     493
# PM2.5    492
# SO2      482
# OZONE    480
# CO       478
# NH3      438
# Name: count, dtype: int64
# ********************
# Unique <bound method IndexOpsMixin.nunique of 0         NO2
# 1          CO
# 2       PM2.5
# 3        PM10
# 4         NH3
#         ...
# 3354     PM10
# 3355      SO2
# 3356    OZONE
# 3357     PM10
# 3358      NH3
# Name: pollutant_id, Length: 3359, dtype: object>
# <bound method Series.unique of 0         NO2
# 1          CO
# 2       PM2.5
# 3        PM10
# 4         NH3
#         ...
# 3354     PM10
# 3355      SO2
# 3356    OZONE
# 3357     PM10
# 3358      NH3
# Name: pollutant_id, Length: 3359, dtype: object>
